# %%
import numpy as np

# %%
#Reference
#https://stackoverflow.com/questions/1904351/python-observer-pattern-examples-tips
# define the subject for observer
class Observer():
    _observers = []
    def __init__(self):
        self._observers.append(self)
        self._observables = dict()
    #create observe event
    def register(self, event_name, callback):
        self._observables[event_name] = callback
    #delete observe event
    def unregister(self, event_name):
        del self._observables[event_name]
    #OO get value for two lists
    def get_observers(self):
        return self._observers
    def get_observables(self):
        return self._observables.keys()
#define the event.
class Event():
    def __init__(self,observers, name, data, autofire = True):
        self.name = name
        self.data = data
        self.observers = observers
        if autofire:
            self.fire()      
    def fire(self):
        for observer in self.observers:
            if self.name in observer._observables:
                print("Hi, this is the Zoo Announcer. The Zookeeper is about to {}!".format(self.name))
                observer._observables[self.name](self.data)

# %%
class Animal():
    def __init__(self,animal_name,function = None):  
        #I use strategy pattern on eat method
        #take input as a function
        if function: self.eat = types.MethodType(function, self)
        self.animal_name = animal_name
    def getName(self):   return self.animal_name
    def sleep(self):     return "This animal sleeps"
    def eat(self):       return "This animal is eating"
    def getType(self):   return "Animal"
    def makeNoise(self): return "This animal is making noise"
    def wakeup(self):    return "This animal is wake up"
    def roam(self):      return "This Animal is roaming"

# %%
class Canine(Animal):
    def roam(self):  return "This Canine is roaming"
    def sleep(self): return "This Canine is sleeping"
    def getspecies(slef): return "Canine";
class Pachyderm(Animal):
    def roam(self):  return "This Pachyderm is roaming"
    def sleep(self): return "This Pachyderm is sleeping"
    def getspecies(self): return "Pachyderm";
class Feline(Animal):
    def roam(self):  return "This Feline is roaming"
    def sleep(self): return "This Feline is sleeping"
    def getspecies(self): return "Feline";

# %%
class cat(Feline):
    def sleep(self): return "This Cat sleeps"
    def roam(self): return "This Cat is roaming"
    def makeNoise(self): return "The Cat makes noise"
    def wakeup(self):return np.random.choice(["Mewwwwww", "This cat is wakeup", "This cat doesn't want to wake up"])   
    def getType(self): return "Cat"
class dog(Canine):
    def roam(self): return "This dog is roaming"
    def makeNoise(self): return "The dog makes noise"
    def getType(self): return "dog"
class elephant(Pachyderm):
    def roam(self): return "This elephant is roaming"
    def makeNoise(self): return "The elephant makes noise"
    def getType(self): return "elephant"
class hippo(Pachyderm):
    def roam(self): return "This hippo is roaming"
    def makeNoise(self): return "The hippo makes noise"
    def getType(self): return "hippo"
class rhino(Pachyderm):
    def roam(self): return "This rhino is roaming"
    def makeNoise(self): return "The rhino makes noise"
    def getType(self): return "rhino"
class lion(Feline):
    def roam(self): return "This lion is roaming"
    def makeNoise(self): return "The lion makes noise"
    def getType(self): return "lion"
class tiger(Feline):
    def roam(self): return "This tiger is roaming"
    def makeNoise(self): return "The tiger makes noise"
    def getType(self): return "tiger"
class wolf(Canine):
    def roam(self): return "This wolf is roaming"
    def makeNoise(self): return "The wolf makes noise"
    def getType(self): return "wolf"

# %%
class Zookeeper(Observer):
    def __init__(self,name):
        self.name = name
        Observer.__init__(self)
    def selfIntroduce(self):
        print("Hi, this is {}. I am the Zookeeper".format(self.name))
    def wakeTheAnimal(self,tmp):
        print("{} wake up {}".format(self.name,tmp.getName()))
    def callAnimal(self,tmp):
        print("{} roll call {}".format(self.name,tmp.getName()))
    def feedAnimal(self,tmp):
        print("{} feed {}".format(self.name,tmp.getName()))
    def closeZoo(self,tmp):
        print("{} let {} go to sleep".format(self.name,tmp.getName()))
    def exercise(self,tmp):
        print("{} train {}".format(self.name,tmp.getName()))

# %%
class Zoo:
    def __init__(self,zookeeper_name):
        self.animals = []
        self.animals_name_list = ["Lily","Liam","Harry","Hulk","David","Dylan","Cathey","Clark","Emily","Eason","Walt","Whiteside","Tom","Tiana","Roy","Richard"]
        for name in self.animals_name_list:
            firstChar = name[0]
            if firstChar == "L":
                self.animals.append(lion(name))
            elif firstChar == "H":
                self.animals.append(hippo(name))
            elif firstChar == "D":
                self.animals.append(dog(name))
            elif firstChar == "C":
                self.animals.append(cat(name))
            elif firstChar == "E":
                self.animals.append(elephant(name))
            elif firstChar == "S":
                self.animals.append(wolf(name))
            elif firstChar == "T":
                self.animals.append(tiger(name))
            elif firstChar == "R":
                self.animals.append(rhino(name))
        self.billy = Zookeeper(zookeeper_name)
    def start_operate(self):
        self.billy.register("wake the animal",self.billy.wakeTheAnimal)
        self.billy.register("call the animal",self.billy.callAnimal)
        self.billy.register("feed the animal",self.billy.feedAnimal)
        self.billy.register("close the Zoo",self.billy.closeZoo)
        self.billy.register("exercise the animal",self.billy.exercise)
        self.billy.selfIntroduce()
        #Responsibilities I
        #Polymorphism: Class Animal    * Cat is random response * Lion is oveeride function in class Lion
        print("------------------------------------------")
        print("\n")
        print("Responsibilities 1: wake the animals")
        for idx,animal in enumerate(self.animals):
            Event(self.billy.get_observers(),"wake the animal",animal)
            print("{} is a {}".format(animal.getName(),animal.getType()))
            print("{}'s species is {}".format(animal.getName(),animal.getspecies()))
            print("{}'s response: {}'".format(animal.getName(),animal.wakeup()))
        print("\n")
        print("------------------------------------------")
        print("\n")
        #Responsibilities II
        #Polymorphism: Class Type of each Animal
        print("Responsibilities 2: roll call the animals")
        for idx,animal in enumerate(self.animals):
            Event(self.billy.get_observers(),"call the animal",animal)
            print("{} is a {}".format(animal.getName(),animal.getType()))
            print("{}'s species is {}".format(animal.getName(),animal.getspecies()))
            print("{}'s response: {}'".format(animal.getName(),animal.makeNoise()))
        print("\n")
        print("------------------------------------------")
        print("\n")        
        #Responsibilities III
        #Polymorphism: Class Animal
        print("Responsibilities 3: feed the animals")
        for idx,animal in enumerate(self.animals):
            Event(self.billy.get_observers(),"feed the animal",animal)
            print("{} is a {}".format(animal.getName(),animal.getType()))
            print("{}'s species is {}".format(animal.getName(),animal.getspecies()))
            print("{}'s response: {}'".format(animal.getName(),animal.eat()))
        print("\n")
        print("------------------------------------------")
        print("\n")        
        #Responsibilities IV
        #Polymorphism: Class Animal
        print("Responsibilities 4: exercise the animals")
        for idx,animal in enumerate(self.animals):
            Event(self.billy.get_observers(),"exercise the animal",animal)
            print("{} is a {}".format(animal.getName(),animal.getType()))
            print("{}'s species is {}".format(animal.getName(),animal.getspecies()))
            print("{}'s response: {}'".format(animal.getName(),animal.roam()))
        print("\n")
        print("------------------------------------------")
        print("\n") 
        #Responsibilities V
        #Responsibilities V
        #Polymorphism: Class Species of each AnimalPolymorphism: Class Species of each Animal
        print("Responsibilities 5: shut down the Zoo")
        for idx,animal in enumerate(self.animals):
            Event(self.billy.get_observers(),"close the Zoo",animal)
            print("{} is a {}".format(animal.getName(),animal.getType()))
            print("{}'s species is {}".format(animal.getName(),animal.getspecies()))
            print("{}'s response: {}'".format(animal.getName(),animal.sleep()))
        print("\n")
        print("------------------------------------------")
        print("\n") 
        for event in ["wake the animal","call the animal","feed the animal","close the Zoo","exercise the animal"]:
            self.billy.unregister(event)

# %%
test = Zoo("Billy")

# %%
test.start_operate()
# Out:
# Hi, this is Billy. I am the Zookeeper
# ------------------------------------------
#
#
# Responsibilities 1: wake the animals
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Lily
# Lily is a lion
# Lily's species is Feline
# Lily's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Liam
# Liam is a lion
# Liam's species is Feline
# Liam's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Harry
# Harry is a hippo
# Harry's species is Pachyderm
# Harry's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Hulk
# Hulk is a hippo
# Hulk's species is Pachyderm
# Hulk's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up David
# David is a dog
# David's species is Canine
# David's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Dylan
# Dylan is a dog
# Dylan's species is Canine
# Dylan's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Cathey
# Cathey is a Cat
# Cathey's species is Feline
# Cathey's response: This cat doesn't want to wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Clark
# Clark is a Cat
# Clark's species is Feline
# Clark's response: Mewwwwww'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Emily
# Emily is a elephant
# Emily's species is Pachyderm
# Emily's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Eason
# Eason is a elephant
# Eason's species is Pachyderm
# Eason's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Tom
# Tom is a tiger
# Tom's species is Feline
# Tom's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Tiana
# Tiana is a tiger
# Tiana's species is Feline
# Tiana's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Roy
# Roy is a rhino
# Roy's species is Pachyderm
# Roy's response: This animal is wake up'
# Hi, this is the Zoo Announcer. The Zookeeper is about to wake the animal!
# Billy wake up Richard
# Richard is a rhino
# Richard's species is Pachyderm
# Richard's response: This animal is wake up'
#
#
# ------------------------------------------
#
#
# Responsibilities 2: roll call the animals
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Lily
# Lily is a lion
# Lily's species is Feline
# Lily's response: The lion makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Liam
# Liam is a lion
# Liam's species is Feline
# Liam's response: The lion makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Harry
# Harry is a hippo
# Harry's species is Pachyderm
# Harry's response: The hippo makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Hulk
# Hulk is a hippo
# Hulk's species is Pachyderm
# Hulk's response: The hippo makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call David
# David is a dog
# David's species is Canine
# David's response: The dog makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Dylan
# Dylan is a dog
# Dylan's species is Canine
# Dylan's response: The dog makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Cathey
# Cathey is a Cat
# Cathey's species is Feline
# Cathey's response: The Cat makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Clark
# Clark is a Cat
# Clark's species is Feline
# Clark's response: The Cat makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Emily
# Emily is a elephant
# Emily's species is Pachyderm
# Emily's response: The elephant makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Eason
# Eason is a elephant
# Eason's species is Pachyderm
# Eason's response: The elephant makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Tom
# Tom is a tiger
# Tom's species is Feline
# Tom's response: The tiger makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Tiana
# Tiana is a tiger
# Tiana's species is Feline
# Tiana's response: The tiger makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Roy
# Roy is a rhino
# Roy's species is Pachyderm
# Roy's response: The rhino makes noise'
# Hi, this is the Zoo Announcer. The Zookeeper is about to call the animal!
# Billy roll call Richard
# Richard is a rhino
# Richard's species is Pachyderm
# Richard's response: The rhino makes noise'
#
#
# ------------------------------------------
#
#
# Responsibilities 3: feed the animals
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Lily
# Lily is a lion
# Lily's species is Feline
# Lily's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Liam
# Liam is a lion
# Liam's species is Feline
# Liam's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Harry
# Harry is a hippo
# Harry's species is Pachyderm
# Harry's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Hulk
# Hulk is a hippo
# Hulk's species is Pachyderm
# Hulk's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed David
# David is a dog
# David's species is Canine
# David's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Dylan
# Dylan is a dog
# Dylan's species is Canine
# Dylan's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Cathey
# Cathey is a Cat
# Cathey's species is Feline
# Cathey's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Clark
# Clark is a Cat
# Clark's species is Feline
# Clark's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Emily
# Emily is a elephant
# Emily's species is Pachyderm
# Emily's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Eason
# Eason is a elephant
# Eason's species is Pachyderm
# Eason's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Tom
# Tom is a tiger
# Tom's species is Feline
# Tom's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Tiana
# Tiana is a tiger
# Tiana's species is Feline
# Tiana's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Roy
# Roy is a rhino
# Roy's species is Pachyderm
# Roy's response: This animal is eating'
# Hi, this is the Zoo Announcer. The Zookeeper is about to feed the animal!
# Billy feed Richard
# Richard is a rhino
# Richard's species is Pachyderm
# Richard's response: This animal is eating'
#
#
# ------------------------------------------
#
#
# Responsibilities 4: exercise the animals
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Lily
# Lily is a lion
# Lily's species is Feline
# Lily's response: This lion is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Liam
# Liam is a lion
# Liam's species is Feline
# Liam's response: This lion is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Harry
# Harry is a hippo
# Harry's species is Pachyderm
# Harry's response: This hippo is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Hulk
# Hulk is a hippo
# Hulk's species is Pachyderm
# Hulk's response: This hippo is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train David
# David is a dog
# David's species is Canine
# David's response: This dog is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Dylan
# Dylan is a dog
# Dylan's species is Canine
# Dylan's response: This dog is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Cathey
# Cathey is a Cat
# Cathey's species is Feline
# Cathey's response: This Cat is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Clark
# Clark is a Cat
# Clark's species is Feline
# Clark's response: This Cat is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Emily
# Emily is a elephant
# Emily's species is Pachyderm
# Emily's response: This elephant is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Eason
# Eason is a elephant
# Eason's species is Pachyderm
# Eason's response: This elephant is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Tom
# Tom is a tiger
# Tom's species is Feline
# Tom's response: This tiger is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Tiana
# Tiana is a tiger
# Tiana's species is Feline
# Tiana's response: This tiger is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Roy
# Roy is a rhino
# Roy's species is Pachyderm
# Roy's response: This rhino is roaming'
# Hi, this is the Zoo Announcer. The Zookeeper is about to exercise the animal!
# Billy train Richard
# Richard is a rhino
# Richard's species is Pachyderm
# Richard's response: This rhino is roaming'
#
#
# ------------------------------------------
#
#
# Responsibilities 5: shut down the Zoo
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Lily go to sleep
# Lily is a lion
# Lily's species is Feline
# Lily's response: This Feline is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Liam go to sleep
# Liam is a lion
# Liam's species is Feline
# Liam's response: This Feline is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Harry go to sleep
# Harry is a hippo
# Harry's species is Pachyderm
# Harry's response: This Pachyderm is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Hulk go to sleep
# Hulk is a hippo
# Hulk's species is Pachyderm
# Hulk's response: This Pachyderm is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let David go to sleep
# David is a dog
# David's species is Canine
# David's response: This Canine is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Dylan go to sleep
# Dylan is a dog
# Dylan's species is Canine
# Dylan's response: This Canine is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Cathey go to sleep
# Cathey is a Cat
# Cathey's species is Feline
# Cathey's response: This Cat sleeps'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Clark go to sleep
# Clark is a Cat
# Clark's species is Feline
# Clark's response: This Cat sleeps'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Emily go to sleep
# Emily is a elephant
# Emily's species is Pachyderm
# Emily's response: This Pachyderm is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Eason go to sleep
# Eason is a elephant
# Eason's species is Pachyderm
# Eason's response: This Pachyderm is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Tom go to sleep
# Tom is a tiger
# Tom's species is Feline
# Tom's response: This Feline is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Tiana go to sleep
# Tiana is a tiger
# Tiana's species is Feline
# Tiana's response: This Feline is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Roy go to sleep
# Roy is a rhino
# Roy's species is Pachyderm
# Roy's response: This Pachyderm is sleeping'
# Hi, this is the Zoo Announcer. The Zookeeper is about to close the Zoo!
# Billy let Richard go to sleep
# Richard is a rhino
# Richard's species is Pachyderm
# Richard's response: This Pachyderm is sleeping'
#
#
# ------------------------------------------
